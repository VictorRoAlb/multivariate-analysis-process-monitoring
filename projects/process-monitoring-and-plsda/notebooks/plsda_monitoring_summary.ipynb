# %% [markdown]
#             # PLS-DA monitoring summary
#
#             This notebook condenses the process-monitoring and discriminant-analysis side of the multivariate repository.
#
#             The project combines:
#             - latent-variable modelling;
#             - cross-validation across components;
#             - class-oriented evaluation;
#             - residual diagnostics;
#             - variable-importance analysis.
#
#             The original workbook-driven environment is not included in the public repository, but the figures below preserve the main analytical views used in the project.

# %% [markdown]
#             ## Cross-validation behaviour
#
#             ![Cross-validation metrics](../figures/01_cv_metricas_vs_A.png)

# %% [markdown]
#             ## Residual diagnostics
#
#             ![Residual diagnostics](../figures/10_diagnostico_residuos_T2_SCRX_SCRY.png)

# %% [markdown]
#             ## Final class-oriented view
#
#             ![Confusion matrix](../figures/11_matriz_confusion_normalizada.png)

# %% [markdown]
#             ## Variable importance
#
#             ![VIP profile](../figures/12_vip.png)
