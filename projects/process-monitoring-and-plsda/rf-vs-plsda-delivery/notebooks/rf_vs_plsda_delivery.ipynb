# %% [markdown]
# # Random Forest and PLS-DA delivery notebook
#
# This notebook keeps only the two supervised models selected for the final delivery: `Random Forest` and `PLS-DA`.

# %% [markdown]
# ## 1. Project setup

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path('..').resolve()
RESULTS = ROOT / 'results'
FIGURES = ROOT / 'figures'
DATA = ROOT / 'data' / 'genz_mental_wellness_synthetic_dataset.csv'

ROOT

# %% [markdown]
# ## 2. Synthetic dataset used in the clean comparison

# %%
df = pd.read_csv(DATA)
df.head()

# %% [markdown]
# ## 3. Final metric table

# %%
metrics = pd.read_csv(RESULTS / 'rf_vs_plsda_metrics.csv')
metrics

# %% [markdown]
# ## 4. PLS-DA component selection

# %%
pls_cv = pd.read_csv(RESULTS / 'plsda_cv_selection.csv')
pls_cv

# %% [markdown]
# ## 5. Figures

# %%
display(Image(filename=str(FIGURES / 'rf_vs_plsda_metrics.png')))
display(Image(filename=str(FIGURES / 'rf_vs_plsda_confusion_matrices.png')))
display(Image(filename=str(FIGURES / 'rf_vs_plsda_importance.png')))

# %% [markdown]
# ## 6. Optional regeneration
#
# If needed, all outputs can be regenerated with:
#
# ```bash
# python src/build_rf_vs_plsda_delivery.py
# ```
